# %% [markdown]
# ### Exercise 1.
#
# Read Total profit of all months and show it using a line plot

# %% [markdown]
# Total profit data provided for each month. Generated line plot must include the following properties:
#
# 1. X label name = Month Number
# 2. Y label name = Total profit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %matplotlib inline

# %%
sales = pd.read_csv("./data/company_sales_data.csv")
sales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
x = sales["month_number"]
totals = sales["total_profit"]

plt.plot(x, totals)
plt.title("Total Profit by Month")
plt.xlabel("Month Number")
plt.ylabel("Total profit")
# Out:
# Text(0, 0.5, 'Total profit')

# %% [markdown]
# ### Exercise 2.
#
# Get total units of all months and show line plot with the following Style properties

# %% [markdown]
# Generated line plot must include following Style properties:
#
# 1. Line Style dotted and Line-color should be red
# 2. Show legend at the lower right location.
# 3. X label name = Month Number
# 4. Y label name = Sold units number
# 5. Add a circle marker.
# 6. Line marker color as read
# 7. Line width should be 3

# %%
units = sales["total_units"]

plt.plot(x, units, 'o', linestyle=":", color='red', linewidth=3, label='# Units')
plt.title("Number of Units Sold Per Month")
plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.legend(loc='lower right')

# %% [markdown]
# ### Exercise 3.
#
# Read all product sales data and show it using a multiline plot
#
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).

# %%
fig = plt.figure(figsize=(11, 5))
plt.plot(x, sales.facecream, label="Facecream")
plt.plot(x, sales.facewash, label="Facewash")
plt.plot(x, sales.toothpaste, label="Toothpaste")
plt.plot(x, sales.bathingsoap, label="Bathing Soap")
plt.plot(x, sales.shampoo, label="Shampoo")
plt.plot(x, sales.moisturizer, label="Moisturizer")
plt.legend(loc="upper left")
plt.title("Amount of Each Product Sold Per Month")
plt.xlabel("Month Number")
plt.ylabel("Number Units Sold")
# Out:
# Text(0, 0.5, 'Number Units Sold')

# %% [markdown]
# ### Exercise 4.
#
# Read toothpaste sales data of each month and show it using a scatter plot
#
# Also, add a grid in the plot. gridline style should “–“.

# %%
plt.scatter(x, sales.toothpaste)
plt.grid(which='both', axis='both', linestyle='-')
plt.title("Number of Toothpaste Units Sold Each Month")
plt.xlabel("Month Number")
plt.ylabel("# Units Sold")
# Out:
# Text(0, 0.5, '# Units Sold')

# %% [markdown]
# ### Exercise 5.
#
# Read face cream and face wash product sales data and show it using the bar chart
#
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
plt.bar(x, sales.facecream, width=0.2, label="Facecream")
plt.bar(x + .2, sales.facewash, width=0.2, label="Facewash")
plt.legend(loc='upper left')
plt.title("Number of Units Sold Each Month")
plt.xlabel("Month Number")
plt.ylabel("# Units Sold")
# Out:
# Text(0, 0.5, '# Units Sold')

# %% [markdown]
# ### Exercise 6.
#
# 1. Write a script that creates your favorite visual type you have learned about, and display the visual once from within the notebook.
# 2. Explain why you chose your visual type.
# 3. Save a copy of the visual once in your choice of vector file formats.
# 4. Save another copy of your visual once in your choice of raster file formats.
# 5. Explain which file format you prefer, and why.

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

fig = plt.figure()
x = sales.total_units
y = sales.total_profit
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

plt.contourf(X, Y, Z, 20, cmap='BrBG')

# %% [markdown]
# I know this visual type doesn't show anything useful about the data here. I chose it because it looks like something I'd like to put on my wall.

# %%
fig.savefig("crazy_plot.svg", format='svg') #vector format
fig.savefig("crzy_plot.png", format='png') #raster format

# %% [markdown]
# I like the vector format better because the color and definition seem to be richer.
